# %%
import joblib
import pandas as pd

# %%
df = pd.read_csv("clean-employee-data.csv")
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      37          1      Travel_Rarely       1141  Research & Development
# 1      51          1      Travel_Rarely       1323  Research & Development
# 2      42          0  Travel_Frequently        555                   Sales
# 3      40          0      Travel_Rarely       1124                   Sales
# 4      55          1      Travel_Rarely        725  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1053   28          1         Non-Travel       1366  Research & Development
# 1054   38          0      Travel_Rarely        168  Research & Development
# 1055   28          1      Travel_Rarely       1485  Research & Development
# 1056   40          0         Non-Travel        458  Research & Development
# 1057   19          1  Travel_Frequently        602                   Sales
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 0                   11          2           Medical                        1
# 1                    4          4     Life Sciences                        1
# 2                   26          3         Marketing                        3
# 3                    1          2           Medical                        2
# 4                    2          3           Medical                        4
# ...                ...        ...               ...                      ...
# 1053                24          2  Technical Degree                        2
# 1054                 1          3     Life Sciences                        3
# 1055                12          1     Life Sciences                        3
# 1056                16          2     Life Sciences                        3
# 1057                 1          1  Technical Degree                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0     Female  ...                  3                         1
# 1       Male  ...                  3                         3
# 2     Female  ...                  3                         4
# 3       Male  ...                  4                         3
# 4       Male  ...                  3                         4
# ...      ...  ...                ...                       ...
# 1053    Male  ...                  3                         1
# 1054  Female  ...                  3                         4
# 1055  Female  ...                  3                         4
# 1056    Male  ...                  3                         2
# 1057  Female  ...                  4                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                15                      2
# 1                    3                18                      2
# 2                    1                23                      2
# 3                    3                 6                      2
# 4                    1                24                      2
# ...                ...               ...                    ...
# 1053                 0                10                      2
# 1054                 0                10                      4
# 1055                 0                 1                      4
# 1056                 1                 6                      0
# 1057                 0                 1                      5
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                  1               1                   0
# 1                  4              10                   0
# 2                  4              20                   4
# 3                  2               4                   3
# 4                  3               5                   2
# ...              ...             ...                 ...
# 1053               2              10                   7
# 1054               4               1                   0
# 1055               2               1                   1
# 1056               3               4                   2
# 1057               4               0                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 0                           0                    0
# 1                           2                    7
# 2                           4                    8
# 3                           0                    2
# 4                           1                    4
# ...                       ...                  ...
# 1053                        1                    9
# 1054                        0                    0
# 1055                        0                    0
# 1056                        0                    0
# 1057                        0                    0
#
# [1058 rows x 31 columns]

# %%
model = joblib.load("model/logistic_mode_gridsearch.pkl")
scaler = joblib.load("model/scaler.pkl")

# %%
current_employees = df[df['Attrition'] == 0].copy()
current_employees.reset_index(inplace=True, drop=True)

selected_columns = [
    "Attrition", "Age", "BusinessTravel", "DistanceFromHome", "EnvironmentSatisfaction",
    "JobInvolvement", "JobSatisfaction", "MonthlyIncome", "OverTime", "RelationshipSatisfaction", "WorkLifeBalance",
    "PerformanceRating", "EducationField", "NumCompaniesWorked", "JobRole", "TotalWorkingYears", "YearsInCurrentRole", "YearsSinceLastPromotion", "YearsWithCurrManager"
]
predict_df = current_employees[selected_columns].copy()

target = "Attrition"

nominal_feature = ["BusinessTravel", "OverTime", "EducationField", "JobRole"]

numerical_feature = predict_df.select_dtypes(
    include=['int64']).columns.drop(target)

predict_df = pd.get_dummies(predict_df, columns=nominal_feature, drop_first=True)

predict_df[numerical_feature] = scaler.fit_transform(predict_df[numerical_feature])
X = predict_df.drop(columns=target)

# %%
current_employees.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   42          0  Travel_Frequently        555                   Sales
# 1   40          0      Travel_Rarely       1124                   Sales
# 2   36          0  Travel_Frequently        635  Research & Development
# 3   32          0      Travel_Rarely       1018  Research & Development
# 4   25          0      Travel_Rarely        583                   Sales
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                26          3      Marketing                        3
# 1                 1          2        Medical                        2
# 2                18          1        Medical                        2
# 3                 3          2  Life Sciences                        3
# 4                 4          1      Marketing                        3
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         4                 1
# 1    Male  ...                  4                         3                 3
# 2  Female  ...                  3                         1                 0
# 3  Female  ...                  3                         4                 0
# 4    Male  ...                  3                         1                 0
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                23                      2               4              20
# 1                 6                      2               2               4
# 2                 8                      2               3               8
# 3                10                      6               3               7
# 4                 5                      1               4               5
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   4                        4                    8
# 1                   3                        0                    2
# 2                   1                        1                    7
# 3                   7                        7                    7
# 4                   2                        0                    3
#
# [5 rows x 31 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 30 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               879 non-null    float64
#  1   DistanceFromHome                  879 non-null    float64
#  2   EnvironmentSatisfaction           879 non-null    float64
#  3   JobInvolvement                    879 non-null    float64
#  4   JobSatisfaction                   879 non-null    float64
#  5   MonthlyIncome                     879 non-null    float64
#  6   RelationshipSatisfaction          879 non-null    float64
#  7   WorkLifeBalance                   879 non-null    float64
#  8   PerformanceRating                 879 non-null    float64
#  9   NumCompaniesWorked                879 non-null    float64
#  10  TotalWorkingYears                 879 non-null    float64
#  11  YearsInCurrentRole                879 non-null    float64
#  12  YearsSinceLastPromotion           879 non-null    float64
#  13  YearsWithCurrManager              879 non-null    float64
#  14  BusinessTravel_Travel_Frequently  879 non-null    bool
#  15  BusinessTravel_Travel_Rarely      879 non-null    bool
#  16  OverTime_Yes                      879 non-null    bool
#  17  EducationField_Life Sciences      879 non-null    bool
#  18  EducationField_Marketing          879 non-null    bool
#  19  EducationField_Medical            879 non-null    bool
#  20  EducationField_Other              879 non-null    bool
#  21  EducationField_Technical Degree   879 non-null    bool
#  22  JobRole_Human Resources           879 non-null    bool
#  23  JobRole_Laboratory Technician     879 non-null    bool
#  24  JobRole_Manager                   879 non-null    bool
#  25  JobRole_Manufacturing Director    879 non-null    bool
#  26  JobRole_Research Director         879 non-null    bool
#  27  JobRole_Research Scientist        879 non-null    bool
#  28  JobRole_Sales Executive           879 non-null    bool
#  29  JobRole_Sales Representative      879 non-null    bool
# dtypes: bool(16), float64(14)
# memory usage: 110.0 KB

# %% [markdown]
# ## Predict the likely hood of current employee leaving the company

# %%
predicted_attrition_risk = model.predict(X)
proba = model.predict_proba(X)[:, 1]
current_employees['PredictedAttrition'] = predicted_attrition_risk
current_employees['AttritionProbability'] = proba
current_employees.sort_values(by='AttritionProbability', ascending=False).head(10)
# Out:
#      Age  Attrition     BusinessTravel  DailyRate              Department  \
# 15    39          0      Travel_Rarely        412  Research & Development
# 511   35          0      Travel_Rarely       1142  Research & Development
# 708   26          0  Travel_Frequently        575  Research & Development
# 418   22          0      Travel_Rarely        217  Research & Development
# 347   36          0      Travel_Rarely        852  Research & Development
# 208   26          0      Travel_Rarely       1443                   Sales
# 674   28          0      Travel_Rarely        760                   Sales
# 372   26          0      Travel_Rarely        192  Research & Development
# 556   27          0      Travel_Rarely       1103  Research & Development
# 534   28          0  Travel_Frequently        193  Research & Development
#
#      DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 15                 13          4        Medical                        3
# 511                23          4        Medical                        3
# 708                 1          2  Life Sciences                        1
# 418                 8          1  Life Sciences                        2
# 347                 5          4  Life Sciences                        2
# 208                23          3      Marketing                        3
# 674                 2          4      Marketing                        2
# 372                 1          2        Medical                        1
# 556                14          3  Life Sciences                        1
# 534                 2          3  Life Sciences                        4
#
#      Gender  ...  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 15   Female  ...                 2                 21                      4
# 511  Female  ...                 1                  4                      3
# 708  Female  ...                 1                  5                      2
# 418    Male  ...                 1                  4                      3
# 347  Female  ...                 1                  6                      3
# 208  Female  ...                 1                  5                      2
# 674  Female  ...                 0                  8                      2
# 372    Male  ...                 2                  6                      2
# 556    Male  ...                 2                  9                      3
# 534    Male  ...                 1                  2                      2
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 15                3              19                  9
# 511               3               2                  2
# 708               3               2                  2
# 418               2               4                  3
# 347               4               1                  1
# 208               2               2                  2
# 674               3               8                  7
# 372               3               5                  3
# 556               2               9                  7
# 534               3               2                  2
#
#      YearsSinceLastPromotion  YearsWithCurrManager  PredictedAttrition  \
# 15                        15                     2                   1
# 511                        2                     2                   1
# 708                        2                     0                   1
# 418                        1                     1                   1
# 347                        0                     0                   1
# 208                        0                     0                   1
# 674                        7                     5                   1
# 372                        1                     3                   1
# 556                        6                     8                   1
# 534                        2                     2                   1
#
#     AttritionProbability
# 15              0.927783
# 511             0.909592
# 708             0.889251
# 418             0.883872
# 347             0.848109
# 208             0.831893
# 674             0.831026
# 372             0.809511
# 556             0.806531
# 534             0.806080
#
# [10 rows x 33 columns]
